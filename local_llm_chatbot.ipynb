# %%
# 安装langchain
# !pip install langchain
# !pip install langchain_openai
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 534.0 kB/s eta 0:00:00 kB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 5.9 MB/s eta 0:00:000:00:010:00:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 785.1/785.1 kB 3.8 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# ...

# %%
# 拉取qwen存储库
# !git clone https://github.com/QwenLM/Qwen.git
# Out:
# Cloning into 'Qwen'...
# remote: Enumerating objects: 1620, done.
# remote: Counting objects: 100% (709/709), done.
# remote: Compressing objects: 100% (224/224), done.
# remote: Total 1620 (delta 559), reused 528 (delta 473), pack-reused 911
# Receiving objects: 100% (1620/1620), 35.49 MiB | 2.45 MiB/s, done.
# Resolving deltas: 100% (958/958), done.

# %%
# 模型下载
from modelscope import snapshot_download
model_dir = snapshot_download('qwen/Qwen-1_8B-Chat', cache_dir='./models')
# Out:
# 2024-02-20 15:58:08,850 - modelscope - INFO - Loading ast index from /home/aiuser/.cache/modelscope/ast_indexer
# 2024-02-20 15:58:08,887 - modelscope - INFO - Loading done! Current index file version is 1.10.0, with md5 e85aa90f4196da77b2023f97a800c04f and a total number of 946 components indexed
# 2024-02-20 15:58:09,367 - modelscope - WARNING - Model revision not specified, use revision: v1.0.0
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8.21k/8.21k [00:00<00:00, 9.01MB/s]
# Downloading: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50.8k/50.8k [00:00<00:00, 952kB/s]
# ...

# %%
# 安装依赖
! cd Qwen && pip install -r requirements.txt && pip install  uvicorn fastapi sse_starlette
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 6.3 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 1.2 MB/s eta 0:00:002.9 MB/s eta 0:00:01
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 8.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 5.3 MB/s eta 0:00:004.6 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 1.8 MB/s eta 0:00:00m eta 0:00:010:00:04
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 4.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 3.4 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 4.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...

# %%
# 修改
# !python Qwen/openai_api.py -c ./models/qwen/Qwen-1_8B-Chat/
# Out:
# /home/aiuser/miniconda3/lib/python3.11/site-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# /home/aiuser/miniconda3/lib/python3.11/site-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# The model is automatically converting to bf16 for faster inference. If you want to disable the automatic precision, please manually add bf16/fp16/fp32=True to "AutoModelForCausalLM.from_pretrained".
# Try importing flash-attention for faster inference...
# ...
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:01<00:00,  1.53it/s]
# INFO:     Started server process [3259587]
# INFO:     Waiting for application startup.
# ...

# %%
from langchain_openai import ChatOpenAI
# 如果有代理地址需要指定 ChatOpenAI(openai_api_base="")
llm = ChatOpenAI(
    openai_api_key='empty',
    openai_api_base='http://127.0.0.1:8000/v1',
    temperature=0.0,
    max_tokens=None
)
print(llm.invoke("写一篇关于langchain的文章"))
# Out:
# content='标题：探索语言链：构建智能交互的未来\n\n随着科技的发展，人工智能已经渗透到我们生活的方方面面。其中，自然语言处理（NLP）是人工智能的重要组成部分，它使得机器能够理解和生成人类语言。然而，目前的人工智能系统仍然存在许多局限性，例如无法理解复杂的语境和情感表达等。\n\n为了解决这些问题，一种新的技术——语言链正在被提出。语言链是一种基于深度学习的新型AI模型，它可以模拟人类大脑的语言处理过程，从而实现更高级别的自然语言处理任务。\n\n语言链的核心思想是将自然语言处理的任务分解成一系列子任务，并通过多层神经网络进行训练。每一层神经网络都负责解决一个特定的子任务，最后的结果就是整个语言链的输出结果。这种模型可以有效地利用大量的数据进行训练，从而提高其性能。\n\n在实际应用中，语言链可以用于多种场景，包括语音识别、文本分类、问答系统等。例如，在语音识别中，语言链可以通过分析用户的语音信号，将其转化为文字信息，然后通过深度学习算法进行识别。在文本分类中，语言链可以根据输入的文本内容，自动对其进行分类，如新闻分类、情感分析等。\n\n此外，语言链还可以用于增强人机交互。例如，当用户与机器人进行对话时，语言链可以帮助机器人理解用户的意图，提供准确的回答。同时，语言链也可以帮助机器人更好地适应不同的环境和情境，提高其交互效率。\n\n总的来说，语言链是一种具有巨大潜力的新一代AI模型，它不仅可以提高人工智能系统的性能，还可以为我们带来更多的便利和可能性。在未来，我们期待看到更多基于语言链的创新应用出现。'
